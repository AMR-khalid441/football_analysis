# %%
# !pip install ultralytics
# !pip install roboflow

# %% [markdown]
# # Get Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ORpGbMcgfJR9ejf58cKg")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# '/content/football-players-detection-1'

# %% [markdown]
# # Training

# %% [markdown]
# # ⚠️ Important: Before any training, make sure data.yaml is updated as follows:
# # names:
# # - ball
# # - goalkeeper
# # - player
# # - referee
# # nc: 4
# # roboflow:
# #   license: CC BY 4.0
# #   project: football-players-detection-3zvbc
# #   url: https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/dataset/1
# #   version: 1
# #   workspace: roboflow-jvuqo
# # test: /content/football-players-detection-1/test/images
# # train: /content/football-players-detection-1/train/images
# # val: /content/football-players-detection-1/valid/images

# %% [markdown]
# OR you can use the code below to edit it

# %%
# ⚠️ Important: Make sure data.yaml is always updated with the correct paths before training
#
# import yaml  # To read and write YAML files
# import os    # To handle file paths
#
# # Path to the YAML file
# yaml_path = "data.yaml"
#
# # The data we want to ensure is always in data.yaml
# data_dict = {
#     "names": ["ball", "goalkeeper", "player", "referee"],  # Object classes
#     "nc": 4,  # Number of classes
#     "roboflow": {  # Roboflow dataset info
#         "license": "CC BY 4.0",
#         "project": "football-players-detection-3zvbc",
#         "url": "https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/dataset/1",
#         "version": 1,
#         "workspace": "roboflow-jvuqo"
#     },
#     # Paths to images for training, validation, and testing
#     "test": "/content/football-players-detection-1/test/images",
#     "train": "/content/football-players-detection-1/train/images",
#     "val": "/content/football-players-detection-1/valid/images"
# }
#
# # Write/update the YAML file
# # This ensures the file always has the correct paths and class info
# with open(yaml_path, "w") as f:
#     yaml.dump(data_dict, f)
#
# # Confirmation message
# print("✅ data.yaml has been updated with correct paths and info")

# %%
# !yolo task=detect mode=train model=yolov5x.pt data="/content/football-players-detection-1/data.yaml" epochs=20 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5x.pt' with new 'model=yolov5xu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics 8.3.216 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
